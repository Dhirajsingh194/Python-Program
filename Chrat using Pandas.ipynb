# %%
import pandas as pd

# %%
f1=pd.read_excel("Analysis sheet.xlsx")

# %%
f1
# Out:
#          Date  Planned  Actual
# 0  2021-10-01       10       9
# 1  2021-10-02       20      19
# 2  2021-10-03       30      29
# 3  2021-10-04       40      39
# 4  2021-10-05       50      49
# 5  2021-10-06       60      59
# 6  2021-10-07       70      69
# 7  2021-10-08       80      84
# 8  2021-10-09       90      95
# 9  2021-10-10      100     110
# 10 2021-10-11      110     120
# 11 2021-10-12      120     125
# 12 2021-10-13      130     139
# 13 2021-10-14      140     147
# 14 2021-10-15      150     157

# %%
f1.plot(figsize=(18,8),x="Date",y=["Planned","Actual"],kind="bar")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
f1.plot(figsize=(18,8),x="Date",y=["Planned","Actual"],kind="line")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
f2=pd.read_excel("Analysis sheet 1.xlsx")

# %%
f2
# Out:
#          Date  Planned  Actual  Pass  Fail  Failure rate Projected(20%)
# 0  2021-11-29       10       5     3     2                         2.00
# 1  2021-11-30       20      16     7     9                         4.00
# 2  2021-12-01       30      21    11    10                         6.00
# 3  2021-12-02       40      33    20    13                         8.00
# 4  2021-12-03       50      35    20    15                        10.00
# 5  2021-12-08       70      47    30    17                        14.00
# 6  2021-12-10       90      80    54    26                        18.00
# 7  2021-12-13      100      88    61    27                        20.00
# 8  2021-12-16      130     127    91    36                        32.50
# 9  2021-12-20      160     129   100    29                        40.00
# 10 2021-12-21      175     141   109    34                        43.75
# 11 2021-12-22      200     158   111    47                        50.00
# ...

# %%
f2.plot(figsize=(18,8),x="Date",y=["Planned","Actual","Pass","Fail"],kind="bar")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
f2.plot(figsize=(18,8),x="Date",y=["Pass","Fail"],kind="line")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import matplotlib.pyplot as plt

# %%
plot = f2.plot.pie(y='Fail', figsize=(10, 10))

# %%
import numpy as np

# %%
df1 = pd.DataFrame(3 * np.random.rand(3), index=['Actual', 'Pass', 'Fail'], columns=['x'])

# %%
df1
# Out:
#                x
# Actual  0.318142
# Pass    1.018233
# Fail    1.146587

# %%
plot = df1.plot.pie(y='x', figsize=(5, 5))
